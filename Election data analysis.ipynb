# %%
import pandas as pd

data = {"State":[
        "Maharashtra",
        "Rajasthan",
        "Gujarat",
        "Uttar Pradesh",
        "Karnataka"
    ],
    "Party": [
        "BJP",
        "INC",
        "BJP",
        "BJP",
        "INC"
    ],
    "Votes": [
        500000,
        450000,
        610000,
        800000,
        420000
    ]
}

df = pd.DataFrame(data)

print(df)
# Out:
#            State Party   Votes
# 0    Maharashtra   BJP  500000
# 1      Rajasthan   INC  450000
# 2        Gujarat   BJP  610000
# 3  Uttar Pradesh   BJP  800000
# 4      Karnataka   INC  420000
